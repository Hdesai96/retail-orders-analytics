# %%
# !pip install kaggle
import kaggle

# !kaggle datasets download ankitbansal06/retail-orders -f orders.csv
# Out:
# ...
# Could not find kaggle.json. Make sure it's located in C:\Users\desai\.kaggle. Or use the environment method. See setup instructions at https://github.com/Kaggle/kaggle-api/
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 get_ipython().system('pip install kaggle')
# ----> 2 import kaggle
#       4 get_ipython().system('kaggle datasets download ankitbansal06/retail-orders -f orders.csv')
#
# File ~\anaconda3\Lib\site-packages\kaggle\__init__.py:10
#       8 enable_oauth = os.environ.get("KAGGLE_ENABLE_OAUTH") in ("1", "true", "yes")
#       9 api = KaggleApi(enable_oauth=enable_oauth)
# ---> 10 api.authenticate()
#
# File ~\anaconda3\Lib\site-packages\kaggle\api\kaggle_api_extended.py:686, in KaggleApi.authenticate(self)
#     679 else:
#     680     print(
#     681         "Could not find {}. Make sure it's located in"
# ...

# %%
import zipfile

zip_ref = zipfile.ZipFile(r"C:\Users\desai\Downloads\archive (3).zip")
zip_ref.extractall()
zip_ref.close()

# %%
import pandas as pd
df = pd.read_csv('orders.csv',na_values=['Not Available','unknown'])
df['Ship Mode'].unique()
# Out:
# array(['Second Class', 'Standard Class', nan, 'First Class', 'Same Day'],
#       dtype=object)

# %%
df.head(20)
# Out:
#     Order Id  Order Date       Ship Mode      Segment        Country  \
# 0          1  2023-03-01    Second Class     Consumer  United States
# 1          2  2023-08-15    Second Class     Consumer  United States
# 2          3  2023-01-10    Second Class    Corporate  United States
# 3          4  2022-06-18  Standard Class     Consumer  United States
# 4          5  2022-07-13  Standard Class     Consumer  United States
# 5          6  2022-03-13             NaN     Consumer  United States
# 6          7  2022-12-28  Standard Class     Consumer  United States
# 7          8  2022-01-25  Standard Class     Consumer  United States
# 8          9  2023-03-23             NaN     Consumer  United States
# 9         10  2023-05-16  Standard Class     Consumer  United States
# 10        11  2023-03-31             NaN     Consumer  United States
# 11        12  2023-12-25             NaN     Consumer  United States
# 12        13  2022-02-11  Standard Class     Consumer  United States
# ...

# %%
df.rename(columns={'Order Id':'order_id', 'City':'city'})
# Out:
#       order_id  Order Date       Ship Mode    Segment        Country  \
# 0            1  2023-03-01    Second Class   Consumer  United States
# 1            2  2023-08-15    Second Class   Consumer  United States
# 2            3  2023-01-10    Second Class  Corporate  United States
# 3            4  2022-06-18  Standard Class   Consumer  United States
# 4            5  2022-07-13  Standard Class   Consumer  United States
# ...        ...         ...             ...        ...            ...
# 9989      9990  2023-02-18    Second Class   Consumer  United States
# 9990      9991  2023-03-17  Standard Class   Consumer  United States
# 9991      9992  2022-08-07  Standard Class   Consumer  United States
# 9992      9993  2022-11-19  Standard Class   Consumer  United States
# 9993      9994  2022-07-17    Second Class   Consumer  United States
#
#                  city       State  Postal Code Region         Category  \
# ...

# %%
df.columns=df.columns.str.lower()
df.columns=df.columns.str.replace(' ','_')

# %%
df['discount']=df['list_price']*df['discount_percent']*.01

# %%
df['sale_price']= df['list_price']-df['discount']

# %%
df['profit']=df['sale_price']-df['cost_price']
df
# Out:
#       order_id  order_date       ship_mode    segment        country  \
# 0            1  2023-03-01    Second Class   Consumer  United States
# 1            2  2023-08-15    Second Class   Consumer  United States
# 2            3  2023-01-10    Second Class  Corporate  United States
# 3            4  2022-06-18  Standard Class   Consumer  United States
# 4            5  2022-07-13  Standard Class   Consumer  United States
# ...        ...         ...             ...        ...            ...
# 9989      9990  2023-02-18    Second Class   Consumer  United States
# 9990      9991  2023-03-17  Standard Class   Consumer  United States
# 9991      9992  2022-08-07  Standard Class   Consumer  United States
# 9992      9993  2022-11-19  Standard Class   Consumer  United States
# 9993      9994  2022-07-17    Second Class   Consumer  United States
#
#                  city       state  postal_code region         category  \
# ...

# %%
df['order_date']=pd.to_datetime(df['order_date'],format="%Y-%m-%d")

# %%
df.drop(columns=['list_price','cost_price','discount_percent'],inplace=True)

# %%
pip install psycopg2-binary
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip install pymysql

# %%
import sqlalchemy as sal
import urllib.parse

user = "root"
password = urllib.parse.quote_plus("Harshmaitrai@96")
host = "localhost"
port = 3306
db = "retail_db"

engine = sal.create_engine(f"mysql+pymysql://{user}:{password}@{host}:{port}/{db}")

# %%
import sqlalchemy as sal
import urllib.parse

user = "root"
password = urllib.parse.quote_plus("Harshmaitrai@96")

root_engine = sal.create_engine(f"mysql+pymysql://{user}:{password}@localhost:3306")

with root_engine.begin() as conn:
    conn.exec_driver_sql("CREATE DATABASE IF NOT EXISTS retail_db;")

# %%
engine = sal.create_engine(f"mysql+pymysql://{user}:{password}@localhost:3306/retail_db")

df.to_sql("df_orders", con=engine, index=False, if_exists="replace", chunksize=5000, method="multi")
# Out:
# 9994
